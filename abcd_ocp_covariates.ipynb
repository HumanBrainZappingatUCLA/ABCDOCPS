# %%
import os
import pandas as pd
from scipy import stats
import statsmodels.formula.api as smf
from statsmodels.stats.multitest import multipletests 
from scipy.stats import spearmanr
from scipy.stats import mannwhitneyu

pd.set_option('display.max_rows', None)  

# Set base directories
base_dir = '/u/home/n/npeterse/BPM/abcd-data-release-5.1/'
oc_work_dir = '/u/home/n/npeterse/oc_work/'

# Load the included participants list
included_participants = pd.read_csv(os.path.join(oc_work_dir, 'included_participants.csv'))
included_subjects = included_participants['src_subject_id']

# Load datasets
ABCD_ct = pd.read_csv(os.path.join(base_dir, 'core/imaging/mri_y_smr_thk_dsk.csv'))
ABCD_pds = pd.read_csv(os.path.join(base_dir, 'core/physical-health/ph_y_pds.csv'))  
ABCD_adi = pd.read_csv(os.path.join(base_dir, 'led_l_adi.csv'))
ABCD_site = pd.read_csv(os.path.join(base_dir, 'core/abcd-general/abcd_y_lt.csv'))
ABCD_hormones = pd.read_csv(os.path.join(base_dir, 'cleaned_hormone_data.csv'))

# Filter to included participants and event name for year 4 data
ABCD_ct = ABCD_ct[(ABCD_ct['src_subject_id'].isin(included_subjects)) & (ABCD_ct['eventname'] == '4_year_follow_up_y_arm_1')]
ABCD_pds = ABCD_pds[(ABCD_pds['src_subject_id'].isin(included_subjects)) & (ABCD_pds['eventname'] == '4_year_follow_up_y_arm_1')]  
ABCD_adi = ABCD_adi[ABCD_adi['src_subject_id'].isin(included_subjects)]
ABCD_site = ABCD_site[(ABCD_site['src_subject_id'].isin(included_subjects)) & (ABCD_site['eventname'] == 'baseline_year_1_arm_1')]
ABCD_hormones = ABCD_hormones[ABCD_hormones['src_subject_id'].isin(included_subjects)]

# Drop duplicates based on 'src_subject_id'
ABCD_ct.drop_duplicates(subset='src_subject_id', inplace=True)
ABCD_pds.drop_duplicates(subset='src_subject_id', inplace=True)
ABCD_adi.drop_duplicates(subset='src_subject_id', inplace=True)
ABCD_site.drop_duplicates(subset='src_subject_id', inplace=True)

# Merge datasets after duplicates are removed
merged_df = pd.merge(ABCD_ct, ABCD_pds[['src_subject_id', 'pds_y_ss_female_category_2', 'menstrualcycle4_y']], on='src_subject_id', how='left')  # Adding youth puberty stage and menstrualcycle4_y
merged_df = pd.merge(merged_df, ABCD_site[['src_subject_id', 'interview_age', 'site_id_l']], on='src_subject_id', how='left')
merged_df = pd.merge(merged_df, ABCD_adi[['src_subject_id', 'reshist_addr1_adi_perc']], on='src_subject_id', how='left')
merged_df = pd.merge(merged_df, ABCD_hormones[['src_subject_id', 'filtered_hormone_scr_dhea', 'filtered_hormone_scr_ert', 'filtered_hormone_scr_hse']], on='src_subject_id', how='left')

# Inspect the first few rows
print(merged_df.head())
# Out:
#      src_subject_id                 eventname  smri_thick_cdk_banksstslh  \
# 0  NDAR_INV028D3ELL  4_year_follow_up_y_arm_1                      2.723
# 1  NDAR_INV02H7G2T6  4_year_follow_up_y_arm_1                      2.665
# 2  NDAR_INV02UVMTY7  4_year_follow_up_y_arm_1                      2.814
# 3  NDAR_INV030W95VP  4_year_follow_up_y_arm_1                      2.512
# 4  NDAR_INV042UJKFB  4_year_follow_up_y_arm_1                      2.647
#
#    smri_thick_cdk_cdacatelh  smri_thick_cdk_cdmdfrlh  smri_thick_cdk_cuneuslh  \
# 0                     2.428                    2.834                    2.005
# 1                     2.779                    2.924                    2.026
# 2                     2.630                    3.040                    2.092
# 3                     2.476                    2.736                    1.972
# 4                     2.979                    2.819                    1.875
#
#    smri_thick_cdk_ehinallh  smri_thick_cdk_fusiformlh  smri_thick_cdk_ifpllh  \
# 0                    2.964                      2.806                  2.653
# 1                    3.116                      3.013                  2.685
# 2                    3.546                      2.840                  2.743
# 3                    3.471                      2.694                  2.727
# 4                    3.532                      2.805                  2.468
#
#    smri_thick_cdk_iftmlh  ...  smri_thick_cdk_meanrh  smri_thick_cdk_mean  \
# 0                  2.854  ...               2.656479             2.648227
# 1                  2.995  ...               2.705531             2.709525
# 2                  2.836  ...               2.849584             2.826331
# 3                  2.788  ...               2.631537             2.616927
# 4                  2.892  ...               2.637513             2.639787
#
#    pds_y_ss_female_category_2  menstrualcycle4_y  interview_age  site_id_l  \
# 0                         4.0                0.0          109.0     site01
# 1                         4.0                0.0          119.0     site17
# 2                         5.0                0.0          130.0     site02
# 3                         5.0                0.0          128.0     site19
# 4                         5.0                0.0          128.0     site14
#
#    reshist_addr1_adi_perc  filtered_hormone_scr_dhea  \
# 0                    22.0                   127.5570
# 1                    24.0                        NaN
# 2                     9.0                    86.6305
# 3                    45.0                   362.8095
# 4                    23.0                   609.3870
#
#    filtered_hormone_scr_ert  filtered_hormone_scr_hse
# 0                    47.931                    1.5540
# 1                       NaN                       NaN
# 2                    36.975                    1.5815
# 3                    94.545                    2.4585
# 4                   136.910                    2.0750
#
# [5 rows x 81 columns]

# %%
# I used this code block to determine which puberty variable to use. I'm not sure why puberty categories
# are listed twice in the code book (category, category_2), but only one contained data, so I used that one. 
# you can also see from this analysis that the parent and child reports have a low-moderate correlation.

# Load datasets
ph_p_pds = pd.read_csv(os.path.join(base_dir, 'core/physical-health/ph_p_pds.csv'))
ph_y_pds = pd.read_csv(os.path.join(base_dir, 'core/physical-health/ph_y_pds.csv'))

# filter to only use relevant year 4 data from participants included in the MRI dataset
included_participants = pd.read_csv('/u/home/n/npeterse/oc_work/included_participants.csv')
included_subjects = included_participants['src_subject_id']
ph_p_pds_filtered = ph_p_pds[(ph_p_pds['src_subject_id'].isin(included_subjects)) & 
                             (ph_p_pds['eventname'] == '4_year_follow_up_y_arm_1')]
ph_y_pds_filtered = ph_y_pds[(ph_y_pds['src_subject_id'].isin(included_subjects)) & 
                             (ph_y_pds['eventname'] == '4_year_follow_up_y_arm_1')]
ph_p_pds_filtered = ph_p_pds_filtered[['src_subject_id', 'pds_p_ss_female_category', 'pds_p_ss_female_category_2']]
ph_y_pds_filtered = ph_y_pds_filtered[['src_subject_id', 'pds_y_ss_female_category', 'pds_y_ss_female_category_2']]

# Merge the two datasets on src_subject_id so we can correlate parent vs youth report
puberty_df = pd.merge(ph_p_pds_filtered, ph_y_pds_filtered, on='src_subject_id', how='inner')

# drop 'src_subject_id' so we don't accidentally try to correlate that with something
numeric_columns = puberty_df.drop(columns=['src_subject_id'])

# Descriptive statistics: counts, means, and standard deviations
desc_stats = numeric_columns.describe()

# Correlations between the puberty stage variables
correlations = numeric_columns.corr()

# Display results
print("Descriptive Statistics (Counts, Means, SDs):")
print(desc_stats)

print("\nCorrelations between the four puberty stage variables:")
print(correlations)
# Out:
# Descriptive Statistics (Counts, Means, SDs):
#        pds_p_ss_female_category  pds_p_ss_female_category_2  \
# count                       0.0                 1149.000000
# mean                        NaN                    4.197563
# std                         NaN                    0.417552
# min                         NaN                    3.000000
# 25%                         NaN                    4.000000
# 50%                         NaN                    4.000000
# 75%                         NaN                    4.000000
# max                         NaN                    5.000000
#
#        pds_y_ss_female_category  pds_y_ss_female_category_2
# count                       0.0                 1211.000000
# mean                        NaN                    4.182494
# std                         NaN                    0.386411
# min                         NaN                    4.000000
# 25%                         NaN                    4.000000
# 50%                         NaN                    4.000000
# 75%                         NaN                    4.000000
# max                         NaN                    5.000000
#
# Correlations between the four puberty stage variables:
#                             pds_p_ss_female_category  \
# pds_p_ss_female_category                         NaN
# pds_p_ss_female_category_2                       NaN
# pds_y_ss_female_category                         NaN
# pds_y_ss_female_category_2                       NaN
#
#                             pds_p_ss_female_category_2  \
# pds_p_ss_female_category                           NaN
# pds_p_ss_female_category_2                    1.000000
# pds_y_ss_female_category                           NaN
# pds_y_ss_female_category_2                    0.284651
#
#                             pds_y_ss_female_category  \
# pds_p_ss_female_category                         NaN
# pds_p_ss_female_category_2                       NaN
# pds_y_ss_female_category                         NaN
# pds_y_ss_female_category_2                       NaN
#
#                             pds_y_ss_female_category_2
# pds_p_ss_female_category                           NaN
# pds_p_ss_female_category_2                    0.284651
# pds_y_ss_female_category                           NaN
# pds_y_ss_female_category_2                    1.000000

# %%
# selecting the brain regions where a significant group difference in thickness emerged 
ct_columns = [col for col in merged_df.columns if col.startswith('smri_thick_cdk_')]

def run_lm(df, ct_column):
    model_formula = f'{ct_column} ~ menstrualcycle4_y'
    try:
        lm_model = smf.ols(model_formula, data=df).fit()
        return lm_model
    except Exception as e:
        print(f"Error fitting model for {ct_column}: {e}")
        return None

# Loop through each cortical thickness column and run the model
significant_results = {}

for column in ct_columns:
    model_result = run_lm(merged_df, column)
    if model_result:
        p_value = model_result.pvalues.get('menstrualcycle4_y', None)  # Get the p-value for menstrualcycle4_y
        if p_value is not None and p_value < 0.05:  # Check if p-value is less than 0.05
            significant_results[column] = {
                'p_value': p_value,
                'coef': model_result.params['menstrualcycle4_y']  # Get the coefficient for menstrualcycle4_y
            }

# Print the cortical thickness measurements with p < 0.05
if significant_results:
    print("Cortical thickness measurements with p < 0.05 for menstrualcycle4_y:")
    for column, stats in significant_results.items():
        print(f"{column}: p = {stats['p_value']:.5f}")
else:
    print("No significant results with p < 0.05 for menstrualcycle4_y.")
# Out:
# Cortical thickness measurements with p < 0.05 for menstrualcycle4_y:
# smri_thick_cdk_mobfrlh: p = 0.01738
# smri_thick_cdk_paracnlh: p = 0.00031
# smri_thick_cdk_ptcatelh: p = 0.01548
# smri_thick_cdk_precnlh: p = 0.01417
# smri_thick_cdk_sufrlh: p = 0.01897
# smri_thick_cdk_supllh: p = 0.04899
# smri_thick_cdk_mobfrrh: p = 0.04870
# smri_thick_cdk_paracnrh: p = 0.00016
# smri_thick_cdk_pcrh: p = 0.02971
# smri_thick_cdk_suplrh: p = 0.01244
# smri_thick_cdk_meanrh: p = 0.03567

# %%
# you can use this block to see how adding each covariate affects the overall model fit for the regions
# where a group difference was observed, given by AIC, BIC, however, in the end, I didn't think this was a 
# useful way to make the decision, since each value is different for each region. we can come back to this 
# and generate some kind of summary score if this method is preferable to what I've done in the supplement

covariates = ['pds_y_ss_female_category_2', 'interview_age', 'reshist_addr1_adi_perc']

# Define the function to run the linear model with covariates
def run_lm_with_covariates(df, ct_column, covariates):
    results = {}
    base_formula = f'{ct_column} ~ menstrualcycle4_y'
    base_model = smf.ols(base_formula, data=df).fit()
    results['base'] = base_model

    # Add each covariate one by one
    for covariate in covariates:
        formula_with_covariate = f'{base_formula} + {covariate}'
        model_with_covariate = smf.ols(formula_with_covariate, data=df).fit()
        results[covariate] = model_with_covariate

    return results

# Loop through significant cortical thickness columns and add covariates
covariate_results = {}

for column in significant_results.keys():
    covariate_results[column] = run_lm_with_covariates(merged_df, column, covariates)
def compare_models(results):
    comparison = []
    for model_name, model in results.items():
        comparison.append({
            'Model': model_name,
            'AIC': model.aic,
            'BIC': model.bic,
            'Adj_R2': model.rsquared_adj
        })
    return pd.DataFrame(comparison)

for column, results in covariate_results.items():
    print(f"\nModel comparisons for {column}:")
    comparison_df = compare_models(results)
    print(comparison_df)
# Out:
# Model comparisons for smri_thick_cdk_mobfrlh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -1757.635470 -1747.399438  0.003775
# 1  pds_y_ss_female_category_2 -1724.084256 -1708.786651  0.004026
# 2               interview_age -1764.488079 -1749.134030  0.010093
# 3      reshist_addr1_adi_perc -1692.987584 -1677.757623  0.002785
#
# Model comparisons for smri_thick_cdk_paracnlh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -1490.711813 -1480.475780  0.009706
# 1  pds_y_ss_female_category_2 -1455.653185 -1440.355580  0.010631
# 2               interview_age -1496.302953 -1480.948904  0.014980
# 3      reshist_addr1_adi_perc -1441.864340 -1426.634379  0.024018
#
# Model comparisons for smri_thick_cdk_ptcatelh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -1712.421451 -1702.185418  0.003940
# 1  pds_y_ss_female_category_2 -1694.069381 -1678.771776  0.002774
# 2               interview_age -1722.391112 -1707.037063  0.012754
# 3      reshist_addr1_adi_perc -1648.151659 -1632.921697  0.004451
#
# Model comparisons for smri_thick_cdk_precnlh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -1598.816678 -1588.580645  0.004066
# 1  pds_y_ss_female_category_2 -1564.544215 -1549.246610  0.006672
# 2               interview_age -1596.823246 -1581.469198  0.003262
# 3      reshist_addr1_adi_perc -1557.823932 -1542.593971  0.026580
#
# Model comparisons for smri_thick_cdk_sufrlh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -1831.745123 -1821.509091  0.003651
# 1  pds_y_ss_female_category_2 -1793.444390 -1778.146785  0.003471
# 2               interview_age -1834.308379 -1818.954330  0.006522
# 3      reshist_addr1_adi_perc -1735.129197 -1719.899236  0.004101
#
# Model comparisons for smri_thick_cdk_supllh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -2057.779353 -2047.543321  0.002333
# 1  pds_y_ss_female_category_2 -2012.534086 -1997.236481  0.001554
# 2               interview_age -2075.822967 -2060.468918  0.017610
# 3      reshist_addr1_adi_perc -1979.522025 -1964.292064  0.014159
#
# Model comparisons for smri_thick_cdk_mobfrrh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -1939.249512 -1929.013479  0.002341
# 1  pds_y_ss_female_category_2 -1895.256543 -1879.958938  0.002093
# 2               interview_age -1957.009928 -1941.655879  0.017392
# 3      reshist_addr1_adi_perc -1865.185285 -1849.955324  0.003180
#
# Model comparisons for smri_thick_cdk_paracnrh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -1592.229253 -1581.993221  0.010709
# 1  pds_y_ss_female_category_2 -1574.354586 -1559.056980  0.010041
# 2               interview_age -1594.546364 -1579.192315  0.013363
# 3      reshist_addr1_adi_perc -1548.876596 -1533.646634  0.032392
#
# Model comparisons for smri_thick_cdk_pcrh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -2155.396482 -2145.160450  0.003022
# 1  pds_y_ss_female_category_2 -2115.918446 -2100.620841  0.002023
# 2               interview_age -2170.191508 -2154.837459  0.015700
# 3      reshist_addr1_adi_perc -2076.421424 -2061.191462  0.012821
#
# Model comparisons for smri_thick_cdk_suplrh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -2092.693127 -2082.457094  0.004252
# 1  pds_y_ss_female_category_2 -2055.577041 -2040.279436  0.003526
# 2               interview_age -2107.394678 -2092.040630  0.016840
# 3      reshist_addr1_adi_perc -2018.472165 -2003.242203  0.014724
#
# Model comparisons for smri_thick_cdk_meanrh:
#                         Model          AIC          BIC    Adj_R2
# 0                        base -2716.106404 -2705.870371  0.002768
# 1  pds_y_ss_female_category_2 -2671.432238 -2656.134633  0.002065
# 2               interview_age -2724.235692 -2708.881643  0.010117
# 3      reshist_addr1_adi_perc -2606.050048 -2590.820086  0.020414

# %%
# instead, I just looked at a whole lot of correlations. this block correlates ADI with every cortical thickness
# measurement, then generates some summary statistics.

adi_column = 'reshist_addr1_adi_perc'
ct_columns = [col for col in merged_df.columns if col.startswith('smri_thick_cdk_')]

# Store correlation and p-value results
correlation_results = []

# Correlate ADI with each cortical thickness region
for column in ct_columns:
    if not merged_df[column].isnull().all() and not merged_df[adi_column].isnull().all():
        corr, p_value = spearmanr(merged_df[adi_column], merged_df[column], nan_policy='omit')  # Spearman's rho correlation
        correlation_results.append({'Region': column, 'Correlation': corr, 'p_value': p_value})

# Convert results to DataFrame for easier manipulation
correlation_df = pd.DataFrame(correlation_results)

# Print each region with its correlation coefficient (r) and p-value
if not correlation_df.empty:
    print(f"Correlation between ADI and cortical thickness for each region:")
    for index, row in correlation_df.iterrows():
        print(f"Region: {row['Region']}, Correlation (r): {row['Correlation']:.5f}, p-value: {row['p_value']:.5e}")

    # Calculate range and average of correlation coefficients and p-values
    min_corr = correlation_df['Correlation'].min()
    max_corr = correlation_df['Correlation'].max()
    avg_corr = correlation_df['Correlation'].mean()
    
    min_p_value = correlation_df['p_value'].min()
    max_p_value = correlation_df['p_value'].max()
    avg_p_value = correlation_df['p_value'].mean()

    # Print summary statistics
    print("\nSummary Statistics:")
    print(f"Range of correlation coefficients: {min_corr:.5f} to {max_corr:.5f}")
    print(f"Average correlation coefficient: {avg_corr:.5f}")
    print(f"Range of p-values: {min_p_value:.5e} to {max_p_value:.5e}")
    print(f"Average p-value: {avg_p_value:.5e}")
else:
    print("No valid correlations were computed.")

adi_column = 'reshist_addr1_adi_perc'
group_column = 'menstrualcycle4_y'

# Split ADI values into two groups based on menstrualcycle4_y (0 and 1)
group_0 = merged_df[merged_df[group_column] == 0][adi_column].dropna()
group_1 = merged_df[merged_df[group_column] == 1][adi_column].dropna()

# Perform the Mann-Whitney U test
u_stat, p_value = mannwhitneyu(group_0, group_1, alternative='two-sided')

# Print the results
print(f"Mann-Whitney U test results:")
print(f"U statistic: {u_stat:.5f}")
print(f"p-value: {p_value:.5e}")

# Optionally, print descriptive statistics for each group
print("\nDescriptive statistics for ADI (reshist_addr1_adi_perc):")
print(f"Group 0 (menstrualcycle4_y = 0): Mean = {group_0.mean():.5f}, Median = {group_0.median():.5f}, N = {len(group_0)}")
print(f"Group 1 (menstrualcycle4_y = 1): Mean = {group_1.mean():.5f}, Median = {group_1.median():.5f}, N = {len(group_1)}")
# Out:
# Correlation between ADI and cortical thickness for each region:
# Region: smri_thick_cdk_banksstslh, Correlation (r): -0.08698, p-value: 2.73920e-03
# Region: smri_thick_cdk_cdacatelh, Correlation (r): -0.01326, p-value: 6.48415e-01
# Region: smri_thick_cdk_cdmdfrlh, Correlation (r): -0.03206, p-value: 2.70345e-01
# Region: smri_thick_cdk_cuneuslh, Correlation (r): -0.09120, p-value: 1.68087e-03
# Region: smri_thick_cdk_ehinallh, Correlation (r): -0.05012, p-value: 8.47270e-02
# Region: smri_thick_cdk_fusiformlh, Correlation (r): -0.05090, p-value: 7.99651e-02
# Region: smri_thick_cdk_ifpllh, Correlation (r): -0.06922, p-value: 1.72173e-02
# Region: smri_thick_cdk_iftmlh, Correlation (r): -0.06846, p-value: 1.84741e-02
# Region: smri_thick_cdk_ihcatelh, Correlation (r): -0.02339, p-value: 4.21355e-01
# Region: smri_thick_cdk_locclh, Correlation (r): -0.12665, p-value: 1.23714e-05
# Region: smri_thick_cdk_lobfrlh, Correlation (r): -0.06642, p-value: 2.22765e-02
# Region: smri_thick_cdk_linguallh, Correlation (r): -0.08428, p-value: 3.70657e-03
# Region: smri_thick_cdk_mobfrlh, Correlation (r): 0.00048, p-value: 9.86963e-01
# Region: smri_thick_cdk_mdtmlh, Correlation (r): -0.06119, p-value: 3.52633e-02
# Region: smri_thick_cdk_parahpallh, Correlation (r): -0.11339, p-value: 9.22564e-05
# Region: smri_thick_cdk_paracnlh, Correlation (r): -0.11767, p-value: 4.92993e-05
# Region: smri_thick_cdk_parsopclh, Correlation (r): -0.00692, p-value: 8.11865e-01
# Region: smri_thick_cdk_parsobislh, Correlation (r): 0.03409, p-value: 2.41086e-01
# Region: smri_thick_cdk_parstgrislh, Correlation (r): -0.05218, p-value: 7.26660e-02
# Region: smri_thick_cdk_pericclh, Correlation (r): -0.08216, p-value: 4.67026e-03
# Region: smri_thick_cdk_postcnlh, Correlation (r): -0.15199, p-value: 1.48023e-07
# Region: smri_thick_cdk_ptcatelh, Correlation (r): -0.03034, p-value: 2.96895e-01
# Region: smri_thick_cdk_precnlh, Correlation (r): -0.14918, p-value: 2.51617e-07
# Region: smri_thick_cdk_pclh, Correlation (r): -0.11845, p-value: 4.39167e-05
# Region: smri_thick_cdk_rracatelh, Correlation (r): -0.03877, p-value: 1.82434e-01
# Region: smri_thick_cdk_rrmdfrlh, Correlation (r): -0.06054, p-value: 3.72541e-02
# Region: smri_thick_cdk_sufrlh, Correlation (r): -0.02123, p-value: 4.65446e-01
# Region: smri_thick_cdk_supllh, Correlation (r): -0.09922, p-value: 6.28635e-04
# Region: smri_thick_cdk_sutmlh, Correlation (r): -0.08915, p-value: 2.13655e-03
# Region: smri_thick_cdk_smlh, Correlation (r): -0.11316, p-value: 9.53886e-05
# Region: smri_thick_cdk_frpolelh, Correlation (r): 0.05514, p-value: 5.78705e-02
# Region: smri_thick_cdk_tmpolelh, Correlation (r): -0.06085, p-value: 3.62941e-02
# Region: smri_thick_cdk_trvtmlh, Correlation (r): -0.06194, p-value: 3.30663e-02
# Region: smri_thick_cdk_insulalh, Correlation (r): -0.00295, p-value: 9.19156e-01
# Region: smri_thick_cdk_banksstsrh, Correlation (r): -0.11825, p-value: 4.52462e-05
# Region: smri_thick_cdk_cdacaterh, Correlation (r): 0.02185, p-value: 4.52513e-01
# Region: smri_thick_cdk_cdmdfrrh, Correlation (r): -0.03155, p-value: 2.78020e-01
# Region: smri_thick_cdk_cuneusrh, Correlation (r): -0.13198, p-value: 5.20312e-06
# Region: smri_thick_cdk_ehinalrh, Correlation (r): -0.04697, p-value: 1.06232e-01
# Region: smri_thick_cdk_fusiformrh, Correlation (r): -0.08275, p-value: 4.38340e-03
# Region: smri_thick_cdk_ifplrh, Correlation (r): -0.07060, p-value: 1.51123e-02
# Region: smri_thick_cdk_iftmrh, Correlation (r): -0.07614, p-value: 8.76834e-03
# Region: smri_thick_cdk_ihcaterh, Correlation (r): -0.04339, p-value: 1.35630e-01
# Region: smri_thick_cdk_loccrh, Correlation (r): -0.15456, p-value: 9.05139e-08
# Region: smri_thick_cdk_lobfrrh, Correlation (r): -0.04223, p-value: 1.46464e-01
# Region: smri_thick_cdk_lingualrh, Correlation (r): -0.08034, p-value: 5.67793e-03
# Region: smri_thick_cdk_mobfrrh, Correlation (r): 0.02555, p-value: 3.79696e-01
# Region: smri_thick_cdk_mdtmrh, Correlation (r): -0.09692, p-value: 8.40406e-04
# Region: smri_thick_cdk_parahpalrh, Correlation (r): -0.14352, p-value: 7.09360e-07
# Region: smri_thick_cdk_paracnrh, Correlation (r): -0.14967, p-value: 2.29330e-07
# Region: smri_thick_cdk_parsopcrh, Correlation (r): -0.04394, p-value: 1.30748e-01
# Region: smri_thick_cdk_parsobisrh, Correlation (r): -0.03400, p-value: 2.42427e-01
# Region: smri_thick_cdk_parstgrisrh, Correlation (r): -0.05253, p-value: 7.07991e-02
# Region: smri_thick_cdk_periccrh, Correlation (r): -0.12027, p-value: 3.33623e-05
# Region: smri_thick_cdk_postcnrh, Correlation (r): -0.15216, p-value: 1.43459e-07
# Region: smri_thick_cdk_ptcaterh, Correlation (r): -0.04234, p-value: 1.45414e-01
# Region: smri_thick_cdk_precnrh, Correlation (r): -0.13700, p-value: 2.23108e-06
# Region: smri_thick_cdk_pcrh, Correlation (r): -0.08221, p-value: 4.64706e-03
# Region: smri_thick_cdk_rracaterh, Correlation (r): 0.07163, p-value: 1.36954e-02
# Region: smri_thick_cdk_rrmdfrrh, Correlation (r): -0.07800, p-value: 7.24687e-03
# Region: smri_thick_cdk_sufrrh, Correlation (r): -0.04937, p-value: 8.94733e-02
# Region: smri_thick_cdk_suplrh, Correlation (r): -0.09290, p-value: 1.37392e-03
# Region: smri_thick_cdk_sutmrh, Correlation (r): -0.12138, p-value: 2.81793e-05
# Region: smri_thick_cdk_smrh, Correlation (r): -0.10766, p-value: 2.06107e-04
# Region: smri_thick_cdk_frpolerh, Correlation (r): 0.03230, p-value: 2.66754e-01
# Region: smri_thick_cdk_tmpolerh, Correlation (r): -0.07956, p-value: 6.16122e-03
# Region: smri_thick_cdk_trvtmrh, Correlation (r): -0.09337, p-value: 1.29800e-03
# Region: smri_thick_cdk_insularh, Correlation (r): -0.05583, p-value: 5.47824e-02
# Region: smri_thick_cdk_meanlh, Correlation (r): -0.11122, p-value: 1.25634e-04
# Region: smri_thick_cdk_meanrh, Correlation (r): -0.12670, p-value: 1.22729e-05
# Region: smri_thick_cdk_mean, Correlation (r): -0.12136, p-value: 2.82604e-05
#
# Summary Statistics:
# Range of correlation coefficients: -0.15456 to 0.07163
# Average correlation coefficient: -0.06935
# Range of p-values: 9.05139e-08 to 9.86963e-01
# Average p-value: 1.17233e-01
# Mann-Whitney U test results:
# U statistic: 33000.50000
# p-value: 3.81572e-01
#
# Descriptive statistics for ADI (reshist_addr1_adi_perc):
# Group 0 (menstrualcycle4_y = 0): Mean = 39.56111, Median = 34.00000, N = 1121
# Group 1 (menstrualcycle4_y = 1): Mean = 42.79365, Median = 41.00000, N = 63

# %%
# and now we do the same thing for age

age_column = 'interview_age'
ct_columns = [col for col in merged_df.columns if col.startswith('smri_thick_cdk_')]

# Add age^2 to the dataframe
merged_df['age_squared'] = merged_df[age_column] ** 2

# Store correlation and p-value results for both age and age^2
correlation_results_age = []
correlation_results_age_squared = []

# Correlate age and age^2 with each cortical thickness region
for column in ct_columns:
    if not merged_df[column].isnull().all() and not merged_df[age_column].isnull().all():
        # Correlate age with cortical thickness
        corr_age, p_value_age = spearmanr(merged_df[age_column], merged_df[column], nan_policy='omit')
        correlation_results_age.append({'Region': column, 'Correlation': corr_age, 'p_value': p_value_age})

        # Correlate age^2 with cortical thickness
        corr_age_squared, p_value_age_squared = spearmanr(merged_df['age_squared'], merged_df[column], nan_policy='omit')
        correlation_results_age_squared.append({'Region': column, 'Correlation': corr_age_squared, 'p_value': p_value_age_squared})

# Convert results to DataFrame for easier manipulation
correlation_df_age = pd.DataFrame(correlation_results_age)
correlation_df_age_squared = pd.DataFrame(correlation_results_age_squared)

# Print each region with its correlation coefficient (r) and p-value for age
if not correlation_df_age.empty:
    print(f"Correlation between age and cortical thickness for each region:")
    for index, row in correlation_df_age.iterrows():
        print(f"Region: {row['Region']}, Correlation (r): {row['Correlation']:.5f}, p-value: {row['p_value']:.5e}")

    # Calculate range and average of correlation coefficients and p-values for age
    min_corr_age = correlation_df_age['Correlation'].min()
    max_corr_age = correlation_df_age['Correlation'].max()
    avg_corr_age = correlation_df_age['Correlation'].mean()
    
    min_p_value_age = correlation_df_age['p_value'].min()
    max_p_value_age = correlation_df_age['p_value'].max()
    avg_p_value_age = correlation_df_age['p_value'].mean()

    print("\nSummary for age:")
    print(f"Range of correlation coefficients: {min_corr_age:.5f} to {max_corr_age:.5f}")
    print(f"Average correlation coefficient: {avg_corr_age:.5f}")
    print(f"Range of p-values: {min_p_value_age:.5e} to {max_p_value_age:.5e}")
    print(f"Average p-value: {avg_p_value_age:.5e}")

# Print each region with its correlation coefficient (r) and p-value for age^2
if not correlation_df_age_squared.empty:
    print(f"\nCorrelation between age^2 and cortical thickness for each region:")
    for index, row in correlation_df_age_squared.iterrows():
        print(f"Region: {row['Region']}, Correlation (r): {row['Correlation']:.5f}, p-value: {row['p_value']:.5e}")

    # Calculate range and average of correlation coefficients and p-values for age^2
    min_corr_age_squared = correlation_df_age_squared['Correlation'].min()
    max_corr_age_squared = correlation_df_age_squared['Correlation'].max()
    avg_corr_age_squared = correlation_df_age_squared['Correlation'].mean()
    
    min_p_value_age_squared = correlation_df_age_squared['p_value'].min()
    max_p_value_age_squared = correlation_df_age_squared['p_value'].max()
    avg_p_value_age_squared = correlation_df_age_squared['p_value'].mean()

    print("\nSummary for age^2:")
    print(f"Range of correlation coefficients: {min_corr_age_squared:.5f} to {max_corr_age_squared:.5f}")
    print(f"Average correlation coefficient: {avg_corr_age_squared:.5f}")
    print(f"Range of p-values: {min_p_value_age_squared:.5e} to {max_p_value_age_squared:.5e}")
    print(f"Average p-value: {avg_p_value_age_squared:.5e}")
# Out:
# Correlation between age and cortical thickness for each region:
# Region: smri_thick_cdk_banksstslh, Correlation (r): -0.06439, p-value: 2.36980e-02
# Region: smri_thick_cdk_cdacatelh, Correlation (r): -0.05144, p-value: 7.08815e-02
# Region: smri_thick_cdk_cdmdfrlh, Correlation (r): -0.04497, p-value: 1.14319e-01
# Region: smri_thick_cdk_cuneuslh, Correlation (r): -0.07661, p-value: 7.09257e-03
# Region: smri_thick_cdk_ehinallh, Correlation (r): -0.03139, p-value: 2.70510e-01
# Region: smri_thick_cdk_fusiformlh, Correlation (r): -0.09778, p-value: 5.82758e-04
# Region: smri_thick_cdk_ifpllh, Correlation (r): -0.14520, p-value: 3.01386e-07
# Region: smri_thick_cdk_iftmlh, Correlation (r): -0.06233, p-value: 2.85534e-02
# Region: smri_thick_cdk_ihcatelh, Correlation (r): -0.05540, p-value: 5.17175e-02
# Region: smri_thick_cdk_locclh, Correlation (r): -0.02573, p-value: 3.66484e-01
# Region: smri_thick_cdk_lobfrlh, Correlation (r): -0.08598, p-value: 2.50508e-03
# Region: smri_thick_cdk_linguallh, Correlation (r): -0.05246, p-value: 6.54418e-02
# Region: smri_thick_cdk_mobfrlh, Correlation (r): -0.09572, p-value: 7.60342e-04
# Region: smri_thick_cdk_mdtmlh, Correlation (r): -0.06048, p-value: 3.36404e-02
# Region: smri_thick_cdk_parahpallh, Correlation (r): -0.03702, p-value: 1.93716e-01
# Region: smri_thick_cdk_paracnlh, Correlation (r): -0.07848, p-value: 5.81086e-03
# Region: smri_thick_cdk_parsopclh, Correlation (r): -0.05210, p-value: 6.73263e-02
# Region: smri_thick_cdk_parsobislh, Correlation (r): -0.05174, p-value: 6.92072e-02
# Region: smri_thick_cdk_parstgrislh, Correlation (r): -0.06912, p-value: 1.51535e-02
# Region: smri_thick_cdk_pericclh, Correlation (r): 0.02146, p-value: 4.51362e-01
# Region: smri_thick_cdk_postcnlh, Correlation (r): -0.07001, p-value: 1.38929e-02
# Region: smri_thick_cdk_ptcatelh, Correlation (r): -0.10239, p-value: 3.14896e-04
# Region: smri_thick_cdk_precnlh, Correlation (r): -0.01462, p-value: 6.07939e-01
# Region: smri_thick_cdk_pclh, Correlation (r): -0.13454, p-value: 2.10616e-06
# Region: smri_thick_cdk_rracatelh, Correlation (r): -0.04001, p-value: 1.60145e-01
# Region: smri_thick_cdk_rrmdfrlh, Correlation (r): -0.08993, p-value: 1.56542e-03
# Region: smri_thick_cdk_sufrlh, Correlation (r): -0.06733, p-value: 1.80013e-02
# Region: smri_thick_cdk_supllh, Correlation (r): -0.12802, p-value: 6.44883e-06
# Region: smri_thick_cdk_sutmlh, Correlation (r): 0.00124, p-value: 9.65336e-01
# Region: smri_thick_cdk_smlh, Correlation (r): -0.02883, p-value: 3.11486e-01
# Region: smri_thick_cdk_frpolelh, Correlation (r): -0.10379, p-value: 2.59975e-04
# Region: smri_thick_cdk_tmpolelh, Correlation (r): -0.00660, p-value: 8.16887e-01
# Region: smri_thick_cdk_trvtmlh, Correlation (r): 0.00367, p-value: 8.97568e-01
# Region: smri_thick_cdk_insulalh, Correlation (r): -0.05137, p-value: 7.12279e-02
# Region: smri_thick_cdk_banksstsrh, Correlation (r): -0.00477, p-value: 8.67137e-01
# Region: smri_thick_cdk_cdacaterh, Correlation (r): -0.04835, p-value: 8.95373e-02
# Region: smri_thick_cdk_cdmdfrrh, Correlation (r): -0.06134, p-value: 3.11866e-02
# Region: smri_thick_cdk_cuneusrh, Correlation (r): -0.04083, p-value: 1.51776e-01
# Region: smri_thick_cdk_ehinalrh, Correlation (r): -0.00261, p-value: 9.27046e-01
# Region: smri_thick_cdk_fusiformrh, Correlation (r): -0.06296, p-value: 2.69918e-02
# Region: smri_thick_cdk_ifplrh, Correlation (r): -0.06561, p-value: 2.11669e-02
# Region: smri_thick_cdk_iftmrh, Correlation (r): -0.04830, p-value: 8.98951e-02
# Region: smri_thick_cdk_ihcaterh, Correlation (r): -0.08292, p-value: 3.55591e-03
# Region: smri_thick_cdk_loccrh, Correlation (r): -0.00765, p-value: 7.88280e-01
# Region: smri_thick_cdk_lobfrrh, Correlation (r): -0.10344, p-value: 2.72914e-04
# Region: smri_thick_cdk_lingualrh, Correlation (r): -0.04271, p-value: 1.33722e-01
# Region: smri_thick_cdk_mobfrrh, Correlation (r): -0.12923, p-value: 5.26353e-06
# Region: smri_thick_cdk_mdtmrh, Correlation (r): -0.07534, p-value: 8.10202e-03
# Region: smri_thick_cdk_parahpalrh, Correlation (r): 0.03221, p-value: 2.58203e-01
# Region: smri_thick_cdk_paracnrh, Correlation (r): -0.06065, p-value: 3.31536e-02
# Region: smri_thick_cdk_parsopcrh, Correlation (r): -0.03563, p-value: 2.11026e-01
# Region: smri_thick_cdk_parsobisrh, Correlation (r): -0.06735, p-value: 1.79780e-02
# Region: smri_thick_cdk_parstgrisrh, Correlation (r): -0.08035, p-value: 4.73834e-03
# Region: smri_thick_cdk_periccrh, Correlation (r): 0.03291, p-value: 2.48011e-01
# Region: smri_thick_cdk_postcnrh, Correlation (r): -0.06541, p-value: 2.15737e-02
# Region: smri_thick_cdk_ptcaterh, Correlation (r): -0.11729, p-value: 3.62350e-05
# Region: smri_thick_cdk_precnrh, Correlation (r): -0.00343, p-value: 9.04081e-01
# Region: smri_thick_cdk_pcrh, Correlation (r): -0.11436, p-value: 5.66562e-05
# Region: smri_thick_cdk_rracaterh, Correlation (r): -0.06647, p-value: 1.95351e-02
# Region: smri_thick_cdk_rrmdfrrh, Correlation (r): -0.13290, p-value: 2.80638e-06
# Region: smri_thick_cdk_sufrrh, Correlation (r): -0.10959, p-value: 1.14528e-04
# Region: smri_thick_cdk_suplrh, Correlation (r): -0.12634, p-value: 8.52970e-06
# Region: smri_thick_cdk_sutmrh, Correlation (r): -0.02514, p-value: 3.77486e-01
# Region: smri_thick_cdk_smrh, Correlation (r): -0.03616, p-value: 2.04359e-01
# Region: smri_thick_cdk_frpolerh, Correlation (r): -0.05093, p-value: 7.36845e-02
# Region: smri_thick_cdk_tmpolerh, Correlation (r): 0.05601, p-value: 4.91551e-02
# Region: smri_thick_cdk_trvtmrh, Correlation (r): -0.06314, p-value: 2.65665e-02
# Region: smri_thick_cdk_insularh, Correlation (r): -0.03275, p-value: 2.50345e-01
# Region: smri_thick_cdk_meanlh, Correlation (r): -0.09956, p-value: 4.60607e-04
# Region: smri_thick_cdk_meanrh, Correlation (r): -0.09806, p-value: 5.61824e-04
# Region: smri_thick_cdk_mean, Correlation (r): -0.10106, p-value: 3.77183e-04
#
# Summary for age:
# Range of correlation coefficients: -0.14520 to 0.05601
# Average correlation coefficient: -0.05903
# Range of p-values: 3.01386e-07 to 9.65336e-01
# Average p-value: 1.62586e-01
#
# Correlation between age^2 and cortical thickness for each region:
# Region: smri_thick_cdk_banksstslh, Correlation (r): -0.06439, p-value: 2.36980e-02
# Region: smri_thick_cdk_cdacatelh, Correlation (r): -0.05144, p-value: 7.08815e-02
# Region: smri_thick_cdk_cdmdfrlh, Correlation (r): -0.04497, p-value: 1.14319e-01
# Region: smri_thick_cdk_cuneuslh, Correlation (r): -0.07661, p-value: 7.09257e-03
# Region: smri_thick_cdk_ehinallh, Correlation (r): -0.03139, p-value: 2.70510e-01
# Region: smri_thick_cdk_fusiformlh, Correlation (r): -0.09778, p-value: 5.82758e-04
# Region: smri_thick_cdk_ifpllh, Correlation (r): -0.14520, p-value: 3.01386e-07
# Region: smri_thick_cdk_iftmlh, Correlation (r): -0.06233, p-value: 2.85534e-02
# Region: smri_thick_cdk_ihcatelh, Correlation (r): -0.05540, p-value: 5.17175e-02
# Region: smri_thick_cdk_locclh, Correlation (r): -0.02573, p-value: 3.66484e-01
# Region: smri_thick_cdk_lobfrlh, Correlation (r): -0.08598, p-value: 2.50508e-03
# Region: smri_thick_cdk_linguallh, Correlation (r): -0.05246, p-value: 6.54418e-02
# Region: smri_thick_cdk_mobfrlh, Correlation (r): -0.09572, p-value: 7.60342e-04
# Region: smri_thick_cdk_mdtmlh, Correlation (r): -0.06048, p-value: 3.36404e-02
# Region: smri_thick_cdk_parahpallh, Correlation (r): -0.03702, p-value: 1.93716e-01
# Region: smri_thick_cdk_paracnlh, Correlation (r): -0.07848, p-value: 5.81086e-03
# Region: smri_thick_cdk_parsopclh, Correlation (r): -0.05210, p-value: 6.73263e-02
# Region: smri_thick_cdk_parsobislh, Correlation (r): -0.05174, p-value: 6.92072e-02
# Region: smri_thick_cdk_parstgrislh, Correlation (r): -0.06912, p-value: 1.51535e-02
# Region: smri_thick_cdk_pericclh, Correlation (r): 0.02146, p-value: 4.51362e-01
# Region: smri_thick_cdk_postcnlh, Correlation (r): -0.07001, p-value: 1.38929e-02
# Region: smri_thick_cdk_ptcatelh, Correlation (r): -0.10239, p-value: 3.14896e-04
# Region: smri_thick_cdk_precnlh, Correlation (r): -0.01462, p-value: 6.07939e-01
# Region: smri_thick_cdk_pclh, Correlation (r): -0.13454, p-value: 2.10616e-06
# Region: smri_thick_cdk_rracatelh, Correlation (r): -0.04001, p-value: 1.60145e-01
# Region: smri_thick_cdk_rrmdfrlh, Correlation (r): -0.08993, p-value: 1.56542e-03
# Region: smri_thick_cdk_sufrlh, Correlation (r): -0.06733, p-value: 1.80013e-02
# Region: smri_thick_cdk_supllh, Correlation (r): -0.12802, p-value: 6.44883e-06
# Region: smri_thick_cdk_sutmlh, Correlation (r): 0.00124, p-value: 9.65336e-01
# Region: smri_thick_cdk_smlh, Correlation (r): -0.02883, p-value: 3.11486e-01
# Region: smri_thick_cdk_frpolelh, Correlation (r): -0.10379, p-value: 2.59975e-04
# Region: smri_thick_cdk_tmpolelh, Correlation (r): -0.00660, p-value: 8.16887e-01
# Region: smri_thick_cdk_trvtmlh, Correlation (r): 0.00367, p-value: 8.97568e-01
# Region: smri_thick_cdk_insulalh, Correlation (r): -0.05137, p-value: 7.12279e-02
# Region: smri_thick_cdk_banksstsrh, Correlation (r): -0.00477, p-value: 8.67137e-01
# Region: smri_thick_cdk_cdacaterh, Correlation (r): -0.04835, p-value: 8.95373e-02
# Region: smri_thick_cdk_cdmdfrrh, Correlation (r): -0.06134, p-value: 3.11866e-02
# Region: smri_thick_cdk_cuneusrh, Correlation (r): -0.04083, p-value: 1.51776e-01
# Region: smri_thick_cdk_ehinalrh, Correlation (r): -0.00261, p-value: 9.27046e-01
# Region: smri_thick_cdk_fusiformrh, Correlation (r): -0.06296, p-value: 2.69918e-02
# Region: smri_thick_cdk_ifplrh, Correlation (r): -0.06561, p-value: 2.11669e-02
# Region: smri_thick_cdk_iftmrh, Correlation (r): -0.04830, p-value: 8.98951e-02
# Region: smri_thick_cdk_ihcaterh, Correlation (r): -0.08292, p-value: 3.55591e-03
# Region: smri_thick_cdk_loccrh, Correlation (r): -0.00765, p-value: 7.88280e-01
# Region: smri_thick_cdk_lobfrrh, Correlation (r): -0.10344, p-value: 2.72914e-04
# Region: smri_thick_cdk_lingualrh, Correlation (r): -0.04271, p-value: 1.33722e-01
# Region: smri_thick_cdk_mobfrrh, Correlation (r): -0.12923, p-value: 5.26353e-06
# Region: smri_thick_cdk_mdtmrh, Correlation (r): -0.07534, p-value: 8.10202e-03
# Region: smri_thick_cdk_parahpalrh, Correlation (r): 0.03221, p-value: 2.58203e-01
# Region: smri_thick_cdk_paracnrh, Correlation (r): -0.06065, p-value: 3.31536e-02
# Region: smri_thick_cdk_parsopcrh, Correlation (r): -0.03563, p-value: 2.11026e-01
# Region: smri_thick_cdk_parsobisrh, Correlation (r): -0.06735, p-value: 1.79780e-02
# Region: smri_thick_cdk_parstgrisrh, Correlation (r): -0.08035, p-value: 4.73834e-03
# Region: smri_thick_cdk_periccrh, Correlation (r): 0.03291, p-value: 2.48011e-01
# Region: smri_thick_cdk_postcnrh, Correlation (r): -0.06541, p-value: 2.15737e-02
# Region: smri_thick_cdk_ptcaterh, Correlation (r): -0.11729, p-value: 3.62350e-05
# Region: smri_thick_cdk_precnrh, Correlation (r): -0.00343, p-value: 9.04081e-01
# Region: smri_thick_cdk_pcrh, Correlation (r): -0.11436, p-value: 5.66562e-05
# Region: smri_thick_cdk_rracaterh, Correlation (r): -0.06647, p-value: 1.95351e-02
# Region: smri_thick_cdk_rrmdfrrh, Correlation (r): -0.13290, p-value: 2.80638e-06
# Region: smri_thick_cdk_sufrrh, Correlation (r): -0.10959, p-value: 1.14528e-04
# Region: smri_thick_cdk_suplrh, Correlation (r): -0.12634, p-value: 8.52970e-06
# Region: smri_thick_cdk_sutmrh, Correlation (r): -0.02514, p-value: 3.77486e-01
# Region: smri_thick_cdk_smrh, Correlation (r): -0.03616, p-value: 2.04359e-01
# Region: smri_thick_cdk_frpolerh, Correlation (r): -0.05093, p-value: 7.36845e-02
# Region: smri_thick_cdk_tmpolerh, Correlation (r): 0.05601, p-value: 4.91551e-02
# Region: smri_thick_cdk_trvtmrh, Correlation (r): -0.06314, p-value: 2.65665e-02
# Region: smri_thick_cdk_insularh, Correlation (r): -0.03275, p-value: 2.50345e-01
# Region: smri_thick_cdk_meanlh, Correlation (r): -0.09956, p-value: 4.60607e-04
# Region: smri_thick_cdk_meanrh, Correlation (r): -0.09806, p-value: 5.61824e-04
# Region: smri_thick_cdk_mean, Correlation (r): -0.10106, p-value: 3.77183e-04
#
# Summary for age^2:
# Range of correlation coefficients: -0.14520 to 0.05601
# Average correlation coefficient: -0.05903
# Range of p-values: 3.01386e-07 to 9.65336e-01
# Average p-value: 1.62586e-01

# %%
# I was just assuming that age and puberty stage correlated, but here it is shown empirically

age_column = 'interview_age'
puberty_column = 'pds_y_ss_female_category_2'
group_column = 'menstrualcycle4_y'

# Mann-Whitney U Test for Age Differences
group_0_age = merged_df[merged_df[group_column] == 0][age_column].dropna()
group_1_age = merged_df[merged_df[group_column] == 1][age_column].dropna()

u_stat_age, p_value_age = mannwhitneyu(group_0_age, group_1_age, alternative='two-sided')

# Print Mann-Whitney U test results for Age
print(f"Mann-Whitney U test for age differences between groups:")
print(f"U statistic: {u_stat_age:.5f}")
print(f"p-value: {p_value_age:.5e}")

# Print the average age for each group
print(f"\nAverage age for group 0 (menstrualcycle4_y = 0): {group_0_age.mean():.2f}")
print(f"Average age for group 1 (menstrualcycle4_y = 1): {group_1_age.mean():.2f}")

# Mann-Whitney U Test for Puberty Stage Differences
group_0_puberty = merged_df[merged_df[group_column] == 0][puberty_column].dropna()
group_1_puberty = merged_df[merged_df[group_column] == 1][puberty_column].dropna()

u_stat_puberty, p_value_puberty = mannwhitneyu(group_0_puberty, group_1_puberty, alternative='two-sided')

# Print Mann-Whitney U test results for Puberty Stage
print(f"\nMann-Whitney U test for puberty stage (pds_y_ss_female_category_2) differences between groups:")
print(f"U statistic: {u_stat_puberty:.5f}")
print(f"p-value: {p_value_puberty:.5e}")

# Print the average puberty stage for each group
print(f"\nAverage puberty stage for group 0 (menstrualcycle4_y = 0): {group_0_puberty.mean():.2f}")
print(f"Average puberty stage for group 1 (menstrualcycle4_y = 1): {group_1_puberty.mean():.2f}")

age_column = 'interview_age'
puberty_column = 'pds_y_ss_female_category_2'

# Correlate age with puberty stage
corr_age_puberty, p_value_age_puberty = spearmanr(merged_df[age_column], merged_df[puberty_column], nan_policy='omit')

# Print the correlation coefficient and p-value
print(f"Spearman correlation between age and puberty stage (pds_y_ss_female_category_2):")
print(f"Correlation (r): {corr_age_puberty:.5f}")
print(f"p-value: {p_value_age_puberty:.5e}")
# Out:
# Mann-Whitney U test for age differences between groups:
# U statistic: 27513.50000
# p-value: 1.76317e-04
#
# Average age for group 0 (menstrualcycle4_y = 0): 119.86
# Average age for group 1 (menstrualcycle4_y = 1): 123.43
#
# Mann-Whitney U test for puberty stage (pds_y_ss_female_category_2) differences between groups:
# U statistic: 32271.50000
# p-value: 1.49755e-02
#
# Average puberty stage for group 0 (menstrualcycle4_y = 0): 4.18
# Average puberty stage for group 1 (menstrualcycle4_y = 1): 4.30
# Spearman correlation between age and puberty stage (pds_y_ss_female_category_2):
# Correlation (r): 0.16680
# p-value: 5.23542e-09

# %%
# and finally, not used in the supplement, relationship between puberty stage and cortical thickness

puberty_column = 'pds_y_ss_female_category_2'
ct_columns = [col for col in merged_df.columns if col.startswith('smri_thick_cdk_')]

# set up a dictionary
correlation_results = []

# Correlate puberty stage with each cortical thickness region
for column in ct_columns:
    if not merged_df[column].isnull().all() and not merged_df[puberty_column].isnull().all():
        corr, p_value = spearmanr(merged_df[puberty_column], merged_df[column], nan_policy='omit')  # Spearman's rho correlation
        correlation_results.append({'Region': column, 'Correlation': corr, 'p_value': p_value})

# Convert results to DataFrame for easier manipulation
correlation_df = pd.DataFrame(correlation_results)

# Print each region with its correlation coefficient (r) and p-value
if not correlation_df.empty:
    print(f"Correlation between puberty stage (pds_y_ss_female_category_2) and cortical thickness for each region:")
    for index, row in correlation_df.iterrows():
        print(f"Region: {row['Region']}, Correlation (r): {row['Correlation']:.5f}, p-value: {row['p_value']:.5e}")

    # Calculate range and average of correlation coefficients and p-values
    min_corr = correlation_df['Correlation'].min()
    max_corr = correlation_df['Correlation'].max()
    avg_corr = correlation_df['Correlation'].mean()
    
    min_p_value = correlation_df['p_value'].min()
    max_p_value = correlation_df['p_value'].max()
    avg_p_value = correlation_df['p_value'].mean()

    # Print summary statistics
    print("\nSummary Statistics:")
    print(f"Range of correlation coefficients: {min_corr:.5f} to {max_corr:.5f}")
    print(f"Average correlation coefficient: {avg_corr:.5f}")
    print(f"Range of p-values: {min_p_value:.5e} to {max_p_value:.5e}")
    print(f"Average p-value: {avg_p_value:.5e}")
else:
    print("No valid correlations were computed.")
# Out:
# Correlation between puberty stage (pds_y_ss_female_category_2) and cortical thickness for each region:
# Region: smri_thick_cdk_banksstslh, Correlation (r): 0.02164, p-value: 4.51896e-01
# Region: smri_thick_cdk_cdacatelh, Correlation (r): -0.00464, p-value: 8.71808e-01
# Region: smri_thick_cdk_cdmdfrlh, Correlation (r): 0.01812, p-value: 5.28778e-01
# Region: smri_thick_cdk_cuneuslh, Correlation (r): -0.06369, p-value: 2.66676e-02
# Region: smri_thick_cdk_ehinallh, Correlation (r): -0.01557, p-value: 5.88224e-01
# Region: smri_thick_cdk_fusiformlh, Correlation (r): -0.01476, p-value: 6.07783e-01
# Region: smri_thick_cdk_ifpllh, Correlation (r): 0.01173, p-value: 6.83359e-01
# Region: smri_thick_cdk_iftmlh, Correlation (r): 0.00728, p-value: 8.00108e-01
# Region: smri_thick_cdk_ihcatelh, Correlation (r): -0.01955, p-value: 4.96669e-01
# Region: smri_thick_cdk_locclh, Correlation (r): 0.02995, p-value: 2.97675e-01
# Region: smri_thick_cdk_lobfrlh, Correlation (r): -0.00921, p-value: 7.48913e-01
# Region: smri_thick_cdk_linguallh, Correlation (r): -0.02871, p-value: 3.18108e-01
# Region: smri_thick_cdk_mobfrlh, Correlation (r): -0.03241, p-value: 2.59760e-01
# Region: smri_thick_cdk_mdtmlh, Correlation (r): 0.03314, p-value: 2.49164e-01
# Region: smri_thick_cdk_parahpallh, Correlation (r): -0.02632, p-value: 3.60211e-01
# Region: smri_thick_cdk_paracnlh, Correlation (r): -0.04222, p-value: 1.42016e-01
# Region: smri_thick_cdk_parsopclh, Correlation (r): 0.04921, p-value: 8.69703e-02
# Region: smri_thick_cdk_parsobislh, Correlation (r): 0.01967, p-value: 4.94047e-01
# Region: smri_thick_cdk_parstgrislh, Correlation (r): 0.02254, p-value: 4.33320e-01
# Region: smri_thick_cdk_pericclh, Correlation (r): 0.02149, p-value: 4.54970e-01
# Region: smri_thick_cdk_postcnlh, Correlation (r): 0.02791, p-value: 3.31804e-01
# Region: smri_thick_cdk_ptcatelh, Correlation (r): -0.02583, p-value: 3.69155e-01
# Region: smri_thick_cdk_precnlh, Correlation (r): 0.05183, p-value: 7.13747e-02
# Region: smri_thick_cdk_pclh, Correlation (r): -0.05882, p-value: 4.07029e-02
# Region: smri_thick_cdk_rracatelh, Correlation (r): 0.01325, p-value: 6.45000e-01
# Region: smri_thick_cdk_rrmdfrlh, Correlation (r): 0.00683, p-value: 8.12206e-01
# Region: smri_thick_cdk_sufrlh, Correlation (r): -0.01244, p-value: 6.65421e-01
# Region: smri_thick_cdk_supllh, Correlation (r): -0.00168, p-value: 9.53548e-01
# Region: smri_thick_cdk_sutmlh, Correlation (r): 0.07498, p-value: 9.05098e-03
# Region: smri_thick_cdk_smlh, Correlation (r): 0.07814, p-value: 6.51574e-03
# Region: smri_thick_cdk_frpolelh, Correlation (r): -0.02048, p-value: 4.76360e-01
# Region: smri_thick_cdk_tmpolelh, Correlation (r): 0.01086, p-value: 7.05661e-01
# Region: smri_thick_cdk_trvtmlh, Correlation (r): 0.03572, p-value: 2.14132e-01
# Region: smri_thick_cdk_insulalh, Correlation (r): -0.00055, p-value: 9.84734e-01
# Region: smri_thick_cdk_banksstsrh, Correlation (r): 0.05795, p-value: 4.37831e-02
# Region: smri_thick_cdk_cdacaterh, Correlation (r): 0.01136, p-value: 6.92986e-01
# Region: smri_thick_cdk_cdmdfrrh, Correlation (r): 0.01716, p-value: 5.50850e-01
# Region: smri_thick_cdk_cuneusrh, Correlation (r): -0.03615, p-value: 2.08688e-01
# Region: smri_thick_cdk_ehinalrh, Correlation (r): 0.01807, p-value: 5.29754e-01
# Region: smri_thick_cdk_fusiformrh, Correlation (r): 0.01031, p-value: 7.20007e-01
# Region: smri_thick_cdk_ifplrh, Correlation (r): 0.05242, p-value: 6.82218e-02
# Region: smri_thick_cdk_iftmrh, Correlation (r): 0.01837, p-value: 5.23157e-01
# Region: smri_thick_cdk_ihcaterh, Correlation (r): -0.04644, p-value: 1.06261e-01
# Region: smri_thick_cdk_loccrh, Correlation (r): 0.01914, p-value: 5.05804e-01
# Region: smri_thick_cdk_lobfrrh, Correlation (r): -0.00498, p-value: 8.62524e-01
# Region: smri_thick_cdk_lingualrh, Correlation (r): 0.01711, p-value: 5.52058e-01
# Region: smri_thick_cdk_mobfrrh, Correlation (r): -0.02545, p-value: 3.76227e-01
# Region: smri_thick_cdk_mdtmrh, Correlation (r): 0.01824, p-value: 5.26068e-01
# Region: smri_thick_cdk_parahpalrh, Correlation (r): 0.02146, p-value: 4.55678e-01
# Region: smri_thick_cdk_paracnrh, Correlation (r): 0.00098, p-value: 9.72865e-01
# Region: smri_thick_cdk_parsopcrh, Correlation (r): 0.03804, p-value: 1.85890e-01
# Region: smri_thick_cdk_parsobisrh, Correlation (r): -0.02782, p-value: 3.33398e-01
# Region: smri_thick_cdk_parstgrisrh, Correlation (r): 0.00251, p-value: 9.30371e-01
# Region: smri_thick_cdk_periccrh, Correlation (r): 0.02393, p-value: 4.05342e-01
# Region: smri_thick_cdk_postcnrh, Correlation (r): 0.04836, p-value: 9.25287e-02
# Region: smri_thick_cdk_ptcaterh, Correlation (r): -0.01085, p-value: 7.06134e-01
# Region: smri_thick_cdk_precnrh, Correlation (r): 0.04393, p-value: 1.26502e-01
# Region: smri_thick_cdk_pcrh, Correlation (r): -0.00540, p-value: 8.51092e-01
# Region: smri_thick_cdk_rracaterh, Correlation (r): 0.02309, p-value: 4.22109e-01
# Region: smri_thick_cdk_rrmdfrrh, Correlation (r): -0.07824, p-value: 6.45070e-03
# Region: smri_thick_cdk_sufrrh, Correlation (r): -0.05054, p-value: 7.87419e-02
# Region: smri_thick_cdk_suplrh, Correlation (r): -0.00849, p-value: 7.67924e-01
# Region: smri_thick_cdk_sutmrh, Correlation (r): 0.04278, p-value: 1.36803e-01
# Region: smri_thick_cdk_smrh, Correlation (r): 0.06018, p-value: 3.62723e-02
# Region: smri_thick_cdk_frpolerh, Correlation (r): -0.03661, p-value: 2.03006e-01
# Region: smri_thick_cdk_tmpolerh, Correlation (r): -0.01057, p-value: 7.13179e-01
# Region: smri_thick_cdk_trvtmrh, Correlation (r): 0.01821, p-value: 5.26763e-01
# Region: smri_thick_cdk_insularh, Correlation (r): 0.04388, p-value: 1.26979e-01
# Region: smri_thick_cdk_meanlh, Correlation (r): 0.01481, p-value: 6.06746e-01
# Region: smri_thick_cdk_meanrh, Correlation (r): 0.01128, p-value: 6.94871e-01
# Region: smri_thick_cdk_mean, Correlation (r): 0.01365, p-value: 6.35117e-01
#
# Summary Statistics:
# Range of correlation coefficients: -0.07824 to 0.07814
# Average correlation coefficient: 0.00652
# Range of p-values: 6.45070e-03 to 9.84734e-01
# Average p-value: 4.43201e-01
